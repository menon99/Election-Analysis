# %%
#WORKING CODE - for TN 

import pandas as pd

#For 1989-1999 datasets

files=['1989.csv','1991.csv','1996.csv','1998.csv','1999.csv']
year_parties=[]

for file in files:
    df=pd.read_csv(file)

    y1=df[df['TERRITORY']=='TAMIL NADU']
    y1=y1[['No.', '%', 'CONSTITUENCY', 'PARTY']]

    j=-1
    unique=list(y1.CONSTITUENCY.unique())
    check=[]
    votes_percent=[]
    party=[]

    for i in y1.index:
        const=y1['CONSTITUENCY'][i]
        if(const in unique and const not in check):
            j+=1
            check.append(const)
            votes_percent.insert(j, y1['%'][i])
            party.insert(j, y1['PARTY'][i])

        if(const in unique and const in check):
            if(y1['%'][i]>votes_percent[j]):
                votes_percent[j]=y1['%'][i]
                party[j]=y1['PARTY'][i]

    f1=pd.DataFrame({'Constituency': check, file.split('.')[0]: party})
    year_parties.append(party)
    #print(f1)
    
#For 2004 dataset

df=pd.read_csv('2004.csv')

y1=df[df['TERRITORY']=='TAMIL NADU']
y1=y1[['No', '% OF TOTAL VOTES', 'CONSTITUENCY', 'PARTY']]

j=-1
unique=list(y1.CONSTITUENCY.unique())
check=[]
votes_percent=[]
party=[]

for i in y1.index:
    const=y1['CONSTITUENCY'][i]
    if(const in unique and const not in check):
        j+=1
        check.append(const)
        votes_percent.insert(j, y1['% OF TOTAL VOTES'][i])
        party.insert(j, y1['PARTY'][i])
        
    if(const in unique and const in check):
        if(y1['% OF TOTAL VOTES'][i]>votes_percent[j]):
            votes_percent[j]=y1['%'][i]
            party[j]=y1['PARTY'][i]

f2=pd.DataFrame({'Constituency': check, '2004': party})
#print(f2)

#2009

cols=['STATE','CONSTITUENCY','CANDIDATE','PARTY','% OF TOTAL VOTES']
df = pd.read_csv("2009.csv",usecols=cols)
df=df[df['STATE']=='Tamil Nadu']

ConstituenciesList = set(df['CONSTITUENCY'])
Candidates_constituency = {}
Winner={}

for item in ConstituenciesList:
    if item not in Candidates_constituency:
        Candidates_constituency[item]=df[df['CONSTITUENCY']==item]
    
for dataframe in Candidates_constituency:
    Candidates_constituency[dataframe]=Candidates_constituency[dataframe].sort_values(by=['% OF TOTAL VOTES'],ascending=False)
    if dataframe not in Winner:
        df_temp=Candidates_constituency[dataframe].head(1)
        WinnerParty=str(df_temp['PARTY'])
        WinnerParty=WinnerParty.split(' ')[4][:-6]
        Winner[dataframe]=WinnerParty

Const=[]
Party2009=[]
for item in Winner:
    Const.append(item)
    Party2009.append(Winner[item])
    
f3=pd.DataFrame({'Constituency': Const, '2009': Party2009})
#print(f3)

#2014

cols=['TERRITORY','CONSTITUENCY','CANDIDATE','PARTY','% OF TOTAL POLLED']
df = pd.read_csv("2014.csv",usecols=cols)
df=df[df['TERRITORY']=='Tamil Nadu']

ConstituenciesList = set(df['CONSTITUENCY'])
Candidates_constituency = {}
Winner={}

for item in ConstituenciesList:
    if item not in Candidates_constituency:
        Candidates_constituency[item]=df[df['CONSTITUENCY']==item]
    
for dataframe in Candidates_constituency:
    Candidates_constituency[dataframe]=Candidates_constituency[dataframe].sort_values(by=['% OF TOTAL POLLED'],ascending=False)
    if dataframe not in Winner:
        df_temp=Candidates_constituency[dataframe].head(1)
        WinnerParty=str(df_temp['PARTY'])
        WinnerParty=WinnerParty.split(' ')[4][:-6]
        Winner[dataframe]=WinnerParty

Const=[]
Party2014=[]
for item in Winner:
    Const.append(item)
    Party2014.append(Winner[item])
    
f4=pd.DataFrame({'Constituency': Const, '2014': Party2014})
#print(f4)


FinalDF1 = pd.DataFrame ({'Constituency':check,'1989':year_parties[0],'1991':year_parties[1],'1996':year_parties[2],'1998':year_parties[3],'1999':year_parties[4],'2004':party})
print (FinalDF1)

FinalDF2 = pd.DataFrame ({'Constituency':Const,'2009':Party2009,'2014':Party2014})
print (FinalDF2)
# Out:
#           Constituency 1989 1991    1996    1998   1999  2004
# 0         MADRAS NORTH  INC  INC     DMK     DMK    DMK   DMK
# 1       MADRAS CENTRAL  INC  INC     DMK     DMK    DMK   DMK
# 2         MADRAS SOUTH  INC  ADK     DMK     DMK    DMK   DMK
# 3   SRIPERUMBUDUR (SC)  INC  INC     DMK    ADMK    DMK   DMK
# 4         CHENGALPATTU  ADK  ADK     DMK    ADMK    PMK   PMK
# 5            ARAKKONAM  INC  INC  TMC(M)    ADMK    DMK   PMK
# 6              VELLORE  INC  INC     DMK     PMK    PMK   DMK
# 7          TIRUPPATTUR  INC  INC     DMK     DMK    DMK   DMK
# 8            VANDAVASI  INC  INC  TMC(M)     PMK    PMK  MDMK
# 9           TINDIVANAM  INC  INC     DMK    MDMK   MDMK   PMK
# 10           CUDDALORE  INC  INC  TMC(M)    ADMK    DMK   DMK
# 11    CHIDAMBARAM (SC)  INC  INC     DMK     PMK    PMK   PMK
# 12          DHARMAPURI  ADK  INC  TMC(M)     PMK    PMK   PMK
# 13         KRISHNAGIRI  INC  INC  TMC(M)    ADMK    DMK   DMK
# ...

# %%
#Consolidating TN Data from 1989 Statewise

import os
import pandas as pd
files=[]

for file in os.listdir(os.getcwd()):
    if not os.path.isdir(file):
        filename=file.split('.')
        if filename[1]=='csv' and int (filename[0])>=1989:
            files.append(file)
        
files=sorted(files) 

#1989
df=pd.read_csv(files[0],usecols=['TERRITORY','CONSTITUENCY','PARTY','%'])
df1 = pd.DataFrame({'YEAR':files[0].split('.')[0],'STATE':df['TERRITORY'],'CONSTITUENCY':df['CONSTITUENCY'],'PARTY':df['PARTY'],'% of VOTES SECURED':df['%']})

#1991
df=pd.read_csv(files[1],usecols=['TERRITORY','CONSTITUENCY','PARTY','%'])
df2=pd.DataFrame({'YEAR':files[1].split('.')[0],'STATE':df['TERRITORY'],'CONSTITUENCY':df['CONSTITUENCY'],'PARTY':df['PARTY'],'% of VOTES SECURED':df['%']})
df1=df1.append(df2,ignore_index=True)

#1996
df=pd.read_csv(files[2],usecols=['TERRITORY','CONSTITUENCY','PARTY','%'])
df2=pd.DataFrame({'YEAR':files[2].split('.')[0],'STATE':df['TERRITORY'],'CONSTITUENCY':df['CONSTITUENCY'],'PARTY':df['PARTY'],'% of VOTES SECURED':df['%']})
df1=df1.append(df2,ignore_index=True)

#1998
df=pd.read_csv(files[3],usecols=['TERRITORY','CONSTITUENCY','PARTY','%'])
df2=pd.DataFrame({'YEAR':files[3].split('.')[0],'STATE':df['TERRITORY'],'CONSTITUENCY':df['CONSTITUENCY'],'PARTY':df['PARTY'],'% of VOTES SECURED':df['%']})
df1=df1.append(df2,ignore_index=True)

#1999
df=pd.read_csv(files[4],usecols=['TERRITORY','CONSTITUENCY','PARTY','%'])
df2=pd.DataFrame({'YEAR':files[4].split('.')[0],'STATE':df['TERRITORY'],'CONSTITUENCY':df['CONSTITUENCY'],'PARTY':df['PARTY'],'% of VOTES SECURED':df['%']})
df1=df1.append(df2,ignore_index=True)

#2004
df=pd.read_csv(files[5],usecols=['TERRITORY','CONSTITUENCY','PARTY','% OF TOTAL VOTES'])
df2=pd.DataFrame({'YEAR':files[5].split('.')[0],'STATE':df['TERRITORY'],'CONSTITUENCY':df['CONSTITUENCY'],'PARTY':df['PARTY'],'% of VOTES SECURED':df['% OF TOTAL VOTES']})
df1=df1.append(df2,ignore_index=True)

#2009
df=pd.read_csv(files[6],usecols=['STATE','CONSTITUENCY','PARTY','% OF TOTAL VOTES'])
df2=pd.DataFrame({'YEAR':files[6].split('.')[0],'STATE':df['STATE'],'CONSTITUENCY':df['CONSTITUENCY'],'PARTY':df['PARTY'],'% of VOTES SECURED':df['% OF TOTAL VOTES']})
df1=df1.append(df2,ignore_index=True)

#2014
df=pd.read_csv(files[7],usecols=['TERRITORY','CONSTITUENCY','PARTY','% OF TOTAL POLLED'])
df2=pd.DataFrame({'YEAR':files[7].split('.')[0],'STATE':df['TERRITORY'],'CONSTITUENCY':df['CONSTITUENCY'],'PARTY':df['PARTY'],'% of VOTES SECURED':df['% OF TOTAL POLLED']})
df1=df1.append(df2,ignore_index=True)

if os.path.isdir('Consolidated'):
    df1.to_csv('./Constituency Wise Vote Share per Candidate 1989-2004.csv')
else:
    os.mkdir('Consolidated')
    df1.to_csv('./Consolidated/Constituency Wise Vote Share per Candidate 1989-2004.csv')
