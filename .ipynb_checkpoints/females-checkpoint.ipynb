# %%
import pandas as pd

# %%
df_1989 = pd.read_csv("1989.csv")

# %%
df_1991 = pd.read_csv("1991.csv")

# %%
df_1996 = pd.read_csv("1996.csv")

# %%
df_1998 = pd.read_csv("1998.csv")

# %%
df_1999 = pd.read_csv("1999.csv")

# %%
df_2004 = pd.read_csv("2004.csv")

# %%
df_2009 = pd.read_csv("2009.csv")

# %%
df_2014 = pd.read_csv("2014.csv")

# %%
df_1989.head()
# Out:
#        %                   CANDIDATE        CONSTITUENCY  No. PARTY SEX  \
# 0  47.70         VISWANATHAM KANITHI          SRIKAKULAM    1   INC   M
# 1  39.41      APPAYYADORA HANUMANTHU          SRIKAKULAM    2   TDP   M
# 2  10.81       BAMMIDI NARAYANASWAMY          SRIKAKULAM    3   IND   M
# 3   2.08               SURYANARAYANA          SRIKAKULAM    4   IND   M
# 4  51.55  VIJAYARAMARAJU SATRUCHARLA  PARVATHIPURAM (ST)    1   INC   M
#
#         TERRITORY   VOTES  TOTAL VOTES POLLED  TOTAL VALID VOTES  \
# 0  ANDHRA PRADESH  288263              632341             604275
# 1  ANDHRA PRADESH  238149              632341             604275
# 2  ANDHRA PRADESH   65317              632341             604275
# 3  ANDHRA PRADESH   12546              632341             604275
# 4  ANDHRA PRADESH  284228              589546             551416
#
#    TOTAL ELECTORS  TOTAL POLL PERCENTAGE
# 0          861650                  73.39
# 1          861650                  73.39
# 2          861650                  73.39
# 3          861650                  73.39
# 4          809362                  72.84

# %%
df_1991.head()
# Out:
#        %                CANDIDATE CONSTITUENCY  No. PARTY SEX       TERRITORY  \
# 0  42.60       VISWANDHAM KANITHI   SRIKAKULAM    1   INC   M  ANDHRA PRADESH
# 1  37.78  APPAYYADORA HANUMANTHLI   SRIKAKULAM    2   TDP   M  ANDHRA PRADESH
# 2  15.06    KINJARAPU YERRANNAIDU   SRIKAKULAM    3   IND   M  ANDHRA PRADESH
# 3   1.96       ATTADA APPALANAIDU   SRIKAKULAM    4   BJP   M  ANDHRA PRADESH
# 4   1.05       ATLA APPOJAMMA (W)   SRIKAKULAM    5   IND   F  ANDHRA PRADESH
#
#     VOTES  TOTAL VOTES POLLED  TOTAL VALID VOTES  TOTAL ELECTORS  \
# 0  235641              568263             553129          860855
# 1  208977              568263             553129          860855
# 2   83292              568263             553129          860855
# 3   10823              568263             553129          860855
# 4    5794              568263             553129          860855
#
#    TOTAL POLL PERCENTAGE
# 0                  66.01
# 1                  66.01
# 2                  66.01
# 3                  66.01
# 4                  66.01

# %%
df_1996.head()
# Out:
#        %                     CANDIDATE CONSTITUENCY  No.       PARTY SEX  \
# 0  36.82         KINJARAPU YERRANNAIDU   SRIKAKULAM    1         TDP   M
# 1  31.38        JAYA KRISHNA MANDAMURI   SRIKAKULAM    2  NTRTDP(LP)   M
# 2  29.63           KANITHI VISWANADHAM   SRIKAKULAM    3         INC   M
# 3   0.99  KRISHNA CHANDRA RAO NAMBALLA   SRIKAKULAM    4         BJP   M
# 4   0.23           KOTA SREENIVASA RAO   SRIKAKULAM    5         IND   M
#
#         TERRITORY   VOTES  TOTAL VOTES POLLED  TOTAL VALID VOTES  \
# 0  ANDHRA PRADESH  234278              647219             636346
# 1  ANDHRA PRADESH  199700              647219             636346
# 2  ANDHRA PRADESH  188559              647219             636346
# 3  ANDHRA PRADESH    6328              647219             636346
# 4  ANDHRA PRADESH    1490              647219             636346
#
#    TOTAL ELECTORS  TOTAL POLL PERCENTAGE
# 0          983329                  65.82
# 1          983329                  65.82
# 2          983329                  65.82
# 3          983329                  65.82
# 4          983329                  65.82

# %%
df_1998.head()
# Out:
#        %                    CANDIDATE        CONSTITUENCY  No.       PARTY  \
# 0  43.14        KINJARAPU YERRANNAIDU          SRIKAKULAM    1         TDP
# 1  30.14      APPAYYA DORA HANUMANTHU          SRIKAKULAM    2  NTRTDP(LP)
# 2  26.46         DHARMANA PRASADA RAO          SRIKAKULAM    3         INC
# 3   0.27     TAMMINENI JAGANMOHANARAO          SRIKAKULAM    4         IND
# 4  50.55  VIJAYA RAMARAJU SETRUCHARLA  PARVATHIPURAM (ST)    1         TDP
#
#   SEX       TERRITORY   VOTES  TOTAL VOTES POLLED  TOTAL VALID VOTES  \
# 0   M  ANDHRA PRADESH  286582              673199             664353
# 1   M  ANDHRA PRADESH  200217              673199             664353
# 2   M  ANDHRA PRADESH  175762              673199             664353
# 3   M  ANDHRA PRADESH    1792              673199             664353
# 4   M  ANDHRA PRADESH  299904              604975             593286
#
#    TOTAL ELECTORS  TOTAL POLL PERCENTAGE
# 0          979623                  68.72
# 1          979623                  68.72
# 2          979623                  68.72
# 3          979623                  68.72
# 4          911746                  66.35

# %%
df_1999.head()
# Out:
#        %                                     CANDIDATE        CONSTITUENCY  \
# 0  56.81                         YERRANNAIDU KINJARAPU          SRIKAKULAM
# 1  42.09                          KANITHI VISWANADAHAM          SRIKAKULAM
# 2   1.11                           APPALA NAIDU GOLIVE          SRIKAKULAM
# 3  49.54           DADICHILUKA VEERA GOURI SANKARA RAO  PARVATHIPURAM (ST)
# 4  47.38  KISHORE CHANDRA SURYANARAYANA DEO VYRICHERLA  PARVATHIPURAM (ST)
#
#    No. PARTY SEX       TERRITORY   VOTES  TOTAL VOTES POLLED  \
# 0    1   TDP   M  ANDHRA PRADESH  373851              676413
# 1    2   INC   M  ANDHRA PRADESH  276969              676413
# 2    3  AJBP   M  ANDHRA PRADESH    7280              676413
# 3    1   TDP   M  ANDHRA PRADESH  304000              637051
# 4    2   INC   M  ANDHRA PRADESH  290719              637051
#
#    TOTAL VALID VOTES  TOTAL ELECTORS  TOTAL POLL PERCENTAGE
# 0             658100          985232                  68.66
# 1             658100          985232                  68.66
# 2             658100          985232                  68.66
# 3             613641          911609                  69.88
# 4             613641          911609                  69.88

# %%
361906*100/723774
# Out:
# 50.00262512883856

# %% [markdown]
# # weed is a chemical

# %%
df_2009.head()
# Out:
#    % OF TOTAL VOTES  % VOTES POLLED  AGE             CANDIDATE CATEGORY  \
# 0              5.12            6.71   55           ADE TUKARAM       ST
# 1             22.74           29.78   39         KOTNAK RAMESH       ST
# 2             32.91           43.11   43         RATHOD RAMESH       ST
# 3              1.46            1.91   50  RATHOD SADASHIV NAIK       ST
# 4              9.98           13.08   59       MESRAM NAGO RAO       ST
#
#    GENERAL VOTES PARTY  POSTAL VOTES SEX  SL NO  TOTAL VOTES CONSTITUENCY  \
# 0          57856   BJP            75   M      1        57931     Adilabad
# 1         257137   INC            44   M      2       257181     Adilabad
# 2         372154   TDP           114   M      3       372268     Adilabad
# 3          16471   BSP             0   M      4        16471     Adilabad
# 4         112914  PRAP            16   M      5       112930     Adilabad
#
#             STATE  TOTAL ELECTORS  TOTAL GENERAL VOTES POLLED  \
# 0  Andhra Pradesh         1131211                      863330
# 1  Andhra Pradesh         1131211                      863330
# 2  Andhra Pradesh         1131211                      863330
# 3  Andhra Pradesh         1131211                      863330
# 4  Andhra Pradesh         1131211                      863330
#
#    TOTAL VOTES POLLED  TOTAL POSTAL VOTES POLLED
# 0              863581                        251
# 1              863581                        251
# 2              863581                        251
# 3              863581                        251
# 4              863581                        251

# %%
max(df_2009["% VOTES POLLED"])
# Out:
# 78.8

# %%
df_2014.head()
# Out:
#         TERRITORY CONSTITUENCY         CANDIDATE SEX   AGE CATEGORY PARTY  \
# 0  Andhra Pradesh    Adilabad       GODAM NAGESH   M  49.0       ST   TRS
# 1  Andhra Pradesh    Adilabad             NARESH   M  37.0       ST   INC
# 2  Andhra Pradesh    Adilabad      RAMESH RATHOD   M  48.0       ST   TDP
# 3  Andhra Pradesh    Adilabad    RATHOD SADASHIV   M  55.0       ST   BSP
# 4  Andhra Pradesh    Adilabad   NETHAWATH RAMDAS   M  44.0       ST   IND
#
#      PARTY SYMBOL  GENERAL VOTES SECURED  POSTAL VOTES SECURED  \
# 0             Car                 425762                  5085
# 1            Hand                 257994                  1563
# 2         Bicycle                 182879                  1319
# 3        Elephant                  94363                    57
# 4  Auto- Rickshaw                  41028                     4
#
#    TOTAL VOTES SECURED  % OF TOTAL VOTES  % OF TOTAL POLLED  TOTAL ELECTORS
# 0               430847         31.079319          40.818072         1386282
# 1               259557         18.723247          24.590206         1386282
# 2               184198         13.287196          17.450759         1386282
# 3                94420          6.811024           8.945269         1386282
# 4                41032          2.959860           3.887336         1386282

# %%
from random import randint,shuffle

# %%
def clean(df,sex):

    s = df[sex].value_counts()
    
    total = 0
    for i in s.keys():
        total += s[i]
    
    d = {}
    for i in s.keys():
        d[i] = int(round(s[i]*100/total))
    
    p = []
    for i in d.keys():
        p += [i]*d[i]
    shuffle(p)
    
    temp = df.loc[df[sex].isnull()]
    index = list(temp.index)
    
    for i in index:
        num = randint(0,99)
        df[sex][i] = p[num]

# %%
df_1989["SEX"].unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
df_1989["SEX"].value_counts()
# Out:
# M    5965
# F     195
# Name: SEX, dtype: int64

# %%
sex = "SEX"

# %%
#clean(df_1989,sex)

# %%
df_1989["SEX"].unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
df_1991[sex].unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
df_1996[sex].unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
df_1998[sex].unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
df_1999[sex].unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
df_2004[sex].unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
df_2009[sex].unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
df_2014[sex].unique()
# Out:
# array(['M', nan, 'F', 'O'], dtype=object)

# %%
df_1989.to_csv("1989.csv",index=False)

# %%
df_1989 = pd.read_csv("1989.csv")

# %%
df_1989.head()
# Out:
#        %                   CANDIDATE        CONSTITUENCY  No. PARTY SEX  \
# 0  47.70         VISWANATHAM KANITHI          SRIKAKULAM    1   INC   M
# 1  39.41      APPAYYADORA HANUMANTHU          SRIKAKULAM    2   TDP   M
# 2  10.81       BAMMIDI NARAYANASWAMY          SRIKAKULAM    3   IND   M
# 3   2.08               SURYANARAYANA          SRIKAKULAM    4   IND   M
# 4  51.55  VIJAYARAMARAJU SATRUCHARLA  PARVATHIPURAM (ST)    1   INC   M
#
#         TERRITORY   VOTES  TOTAL VOTES POLLED  TOTAL VALID VOTES  \
# 0  ANDHRA PRADESH  288263              632341             604275
# 1  ANDHRA PRADESH  238149              632341             604275
# 2  ANDHRA PRADESH   65317              632341             604275
# 3  ANDHRA PRADESH   12546              632341             604275
# 4  ANDHRA PRADESH  284228              589546             551416
#
#    TOTAL ELECTORS  TOTAL POLL PERCENTAGE
# 0          861650                  73.39
# 1          861650                  73.39
# 2          861650                  73.39
# 3          861650                  73.39
# 4          809362                  72.84

# %%
#df_1989["TERRITORY"]
#df_1989["CONSTITUENCY"]
temp = df_1989[0:5]

# %%
temp.index[0]
# Out:
# 0

# %%
temp["TOTAL VOTES POLLED"][temp.index[0]]
# Out:
# 632341

# %%
temp["TOTAL VALID VOTES"]
# Out:
# 0    604275
# 1    604275
# 2    604275
# 3    604275
# 4    551416
# Name: TOTAL VALID VOTES, dtype: int64

# %%
df_1989["TERRITORY"].unique()  #31
# Out:
# array(['ANDHRA PRADESH', 'ARUNACHAL PRADESH', 'BIHAR', 'GOA', 'GUJARAT',
#        'HARYANA', 'HIMACHAL PRADESH', 'JAMMU & KASHMIR', 'KARNATAKA',
#        'KERALA', 'MADHYA PRADESH', 'MAHARASHTRA', 'MANIPUR', 'MEGHALAYA',
#        'MIZORAM', 'NAGALAND', 'ORISSA', 'PUNJAB', 'RAJASTHAN', 'SIKKIM',
#        'TAMIL NADU', 'TRIPURA', 'UTTAR PRADESH', 'WEST BENGAL',
#        'ANDAMAN & NICOBAR ISLANDS', 'CHANDIGARH', 'DADRA & NAGAR HAVELI',
#        'DAMAN & DIU', 'NATIONAL CAPITAL TERRITORY OF DELHI',
#        'LAKSHADWEEP', 'PONDICHERRY'], dtype=object)

# %%
df_1991["TERRITORY"].unique() #30
# Out:
# array(['ANDHRA PRADESH', 'ARUNACHAL PRADESH', 'ASSAM', 'BIHAR', 'GOA',
#        'GUJARAT', 'HARYANA', 'HIMACHAL PRADESH', 'KARNATAKA', 'KERALA',
#        'MADHYA PRADESH', 'MAHARASHTRA', 'MANIPUR', 'MEGHALAYA', 'MIZORAM',
#        'NAGALAND', 'ORISSA', 'RAJASTHAN', 'SIKKIM', 'TAMIL NADU',
#        'TRIPURA', 'UTTAR PRADESH', 'WEST BENGAL',
#        'ANDAMAN & NICOBAR ISLANDS', 'CHANDIGARH', 'DADRA & NAGAR HAVELI',
#        'DAMAN & DIU', 'NATIONAL CAPITAL TERRITORY OF DELHI',
#        'LAKSHADWEEP', 'PONDICHERRY'], dtype=object)

# %%
df_1996["TERRITORY"].unique() #32
# Out:
# array(['ANDHRA PRADESH', 'ARUNACHAL PRADESH', 'ASSAM', 'BIHAR', 'GOA',
#        'GUJARAT', 'HARYANA', 'HIMACHAL PRADESH', 'JAMMU & KASHMIR',
#        'KARNATAKA', 'KERALA', 'MADHYA PRADESH', 'MAHARASHTRA', 'MANIPUR',
#        'MEGHALAYA', 'MIZORAM', 'NAGALAND', 'ORISSA', 'PUNJAB',
#        'RAJASTHAN', 'SIKKIM', 'TAMIL NADU', 'TRIPURA', 'UTTAR PRADESH',
#        'WEST BENGAL', 'ANDAMAN & NICOBAR ISLANDS', 'CHANDIGARH',
#        'DADRA & NAGAR HAVELI', 'DAMAN & DIU',
#        'NATIONAL CAPITAL TERRITORY OF DELHI', 'LAKSHADWEEP',
#        'PONDICHERRY'], dtype=object)

# %%
df_1998["TERRITORY"].unique() == df_1996["TERRITORY"].unique()
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True])

# %%
len(df_1999["TERRITORY"].unique())
# Out:
# 32

# %%
df_2004["TERRITORY"].unique() #35
# Out:
# array(['ANDHRA PRADESH', 'ARUNACHAL PRADESH', 'ASSAM', 'BIHAR', 'GOA',
#        'GUJARAT', 'HARYANA', 'HIMACHAL PRADESH', 'JAMMU & KASHMIR',
#        'KARNATAKA', 'KERALA', 'MADHYA PRADESH', 'MAHARASHTRA', 'MANIPUR',
#        'MEGHALAYA', 'MIZORAM', 'NAGALAND', 'ORISSA', 'PUNJAB',
#        'RAJASTHAN', 'SIKKIM', 'TAMIL NADU', 'TRIPURA', 'UTTAR PRADESH',
#        'WEST BENGAL', 'CHHATTISGARH', 'JHARKHAND', 'UTTARANCHAL',
#        'ANDAMAN & NICOBAR ISLANDS', 'CHANDIGARH', 'DADRA & NAGAR HAVELI',
#        'DAMAN & DIU', 'NATIONAL CAPITAL TERRITORY OF DELHI',
#        'LAKSHADWEEP', 'PONDICHERRY'], dtype=object)

# %%
df_2009["STATE"].unique()
# Out:
# array(['Andhra Pradesh', 'Arunachal Pradesh', 'Assam', 'Bihar', 'Goa',
#        'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir',
#        'Karnataka', 'Kerala', 'Madhya Pradesh', 'Maharashtra', 'Manipur',
#        'Meghalaya', 'Mizoram', 'Nagaland', 'Orissa', 'Punjab',
#        'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Tripura', 'Uttar Pradesh',
#        'West Bengal', 'Chattisgarh', 'Jharkhand', 'Uttarakhand',
#        'Andaman & Nicobar Islands', 'Chandigarh', 'Dadra & Nagar Haveli',
#        'Daman & Diu', 'NCT OF Delhi', 'Lakshadweep', 'Puducherry'],
#       dtype=object)

# %%
df_2014["TERRITORY"].unique()
# Out:
# array(['Andhra Pradesh', 'Arunachal Pradesh', 'Assam', 'Bihar', 'Goa',
#        'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir',
#        'Karnataka', 'Kerala', 'Madhya Pradesh', 'Maharashtra', 'Manipur',
#        'Meghalaya', 'Mizoram', 'Nagaland', 'Punjab', 'Rajasthan',
#        'Sikkim', 'Tamil Nadu', 'Tripura', 'Uttar Pradesh', 'West Bengal',
#        'Jharkhand', 'Uttarakhand', 'Andaman & Nicobar Islands',
#        'Chandigarh', 'Dadra & Nagar Haveli', 'Daman & Diu',
#        'NCT OF Delhi', 'Lakshadweep', 'Puducherry'], dtype=object)

# %%
class fem:
    
    d = {}
    
    def __init__(self,s,c,df):
        
        d['state'] = s
        d['constituency'] = c
        #temp = df.loc[(df["TERRITORY"] == s) & (df["CONSTITUENCY"] == c)]

# %%
states = list(df_1989["TERRITORY"].unique())

# %%
states
# Out:
# ['ANDHRA PRADESH',
#  'ARUNACHAL PRADESH',
#  'BIHAR',
#  'GOA',
#  'GUJARAT',
#  'HARYANA',
#  'HIMACHAL PRADESH',
#  'JAMMU & KASHMIR',
#  'KARNATAKA',
#  'KERALA',
#  'MADHYA PRADESH',
#  'MAHARASHTRA',
#  'MANIPUR',
#  'MEGHALAYA',
#  'MIZORAM',
#  'NAGALAND',
#  'ORISSA',
#  'PUNJAB',
#  'RAJASTHAN',
#  'SIKKIM',
#  'TAMIL NADU',
#  'TRIPURA',
#  'UTTAR PRADESH',
#  'WEST BENGAL',
#  'ANDAMAN & NICOBAR ISLANDS',
#  'CHANDIGARH',
#  'DADRA & NAGAR HAVELI',
#  'DAMAN & DIU',
#  'NATIONAL CAPITAL TERRITORY OF DELHI',
#  'LAKSHADWEEP',
#  'PONDICHERRY']

# %%
state = states[0]

# %%
state
# Out:
# 'ANDHRA PRADESH'

# %%
t1 = df_1989.loc[df_1989["TERRITORY"] == state]

# %%
t1
# Out:
#          %                                    CANDIDATE        CONSTITUENCY  \
# 242             612076          959004                  67.41
# 243             612076          959004                  67.41
# 244             680618          946078                  75.50
# 245             680618          946078                  75.50
# 246             680618          946078                  75.50
# 247             680618          946078                  75.50
# 248             680618          946078                  75.50
# 249             680618          946078                  75.50
# 250             781933         1038053                  78.38
# 251             781933         1038053                  78.38
# 252             781933         1038053                  78.38
# 253             781933         1038053                  78.38
# 254             781933         1038053                  78.38
# 255             745471         1144127                  68.56
# 256             745471         1144127                  68.56
# 257             745471         1144127                  68.56
# 258             745471         1144127                  68.56
# 259             745471         1144127                  68.56
# 260             745471         1144127                  68.56
# 261             745471         1144127                  68.56
# 262             787440         1091124                  74.80
# 263             787440         1091124                  74.80
# 264             787440         1091124                  74.80
# 265             787440         1091124                  74.80
# 266             787440         1091124                  74.80
#
# [267 rows x 12 columns]

# %%
288263*100/604275
# Out:
# 47.70394274130156

# %%
df_temp = pd.DataFrame(columns = ['year','won','contested','total_participation','perc'])

# %%
df_temp
# Out:
# Empty DataFrame
# Columns: [year, won, contested, total_participation, perc]
# Index: []

# %%
const = list(t1["CONSTITUENCY"].unique())

# %%
const
# Out:
# ['SRIKAKULAM',
#  'PARVATHIPURAM (ST)',
#  'BOBBILI',
#  'VISAKHAPATNAM',
#  'BHADRACHALAM (ST)',
#  'ANAKAPALLI',
#  'KAKINADA',
#  'RAJAHMUNDRY',
#  'AMALAPURAM (SC)',
#  'NARASAPUR',
#  'ELURU',
#  'MACHILIPATNAM',
#  'VIJAYAWADA',
#  'TENALI',
#  'GUNTUR',
#  'BAPATLA',
#  'NARASARAOPET',
#  'ONGOLE',
#  'NELLORE (SC)',
#  'TIRUPATHI (SC)',
#  'CHITTOOR',
#  'RAJAMPET',
#  'CUDDAPAH',
#  'HINDUPUR',
#  'ANANTAPUR',
#  'KURNOOL',
#  'NANDYAL',
#  'NAGARKURNOOL (SC)',
#  'MAHABUBNAGAR',
#  'HYDERABAD',
#  'SECUNDERABAD',
#  'SIDDIPET (SC)',
#  'MEDAK',
#  'NIZAMABAD',
#  'ADILABAD',
#  'PEDDAPALLI (SC)',
#  'KARIMNAGAR',
#  'HANAMKONDA',
#  'WARANGAL',
#  'KHAMMAM',
#  'NALGONDA',
#  'MIRYALGUDA']

# %%
won = 0
contested = 0
tp = 0
votes = 0
tv = 0

# %%
c1 = const[0]

# %%
c1
# Out:
# 'SRIKAKULAM'

# %%
tc = t1.loc[t1["CONSTITUENCY"] == c1]

# %%
tc
# Out:
#        %               CANDIDATE CONSTITUENCY  No. PARTY SEX       TERRITORY  \
# 0  47.70     VISWANATHAM KANITHI   SRIKAKULAM    1   INC   M  ANDHRA PRADESH
# 1  39.41  APPAYYADORA HANUMANTHU   SRIKAKULAM    2   TDP   M  ANDHRA PRADESH
# 2  10.81   BAMMIDI NARAYANASWAMY   SRIKAKULAM    3   IND   M  ANDHRA PRADESH
# 3   2.08           SURYANARAYANA   SRIKAKULAM    4   IND   M  ANDHRA PRADESH
#
#     VOTES  TOTAL VOTES POLLED  TOTAL VALID VOTES  TOTAL ELECTORS  \
# 0  288263              632341             604275          861650
# 1  238149              632341             604275          861650
# 2   65317              632341             604275          861650
# 3   12546              632341             604275          861650
#
#    TOTAL POLL PERCENTAGE
# 0                  73.39
# 1                  73.39
# 2                  73.39
# 3                  73.39

# %%
ti = list(tc.index)

# %%
tc["TOTAL VALID VOTES"][ti[0]]
# Out:
# 604275

# %%
f = df_1989.loc[df_1989["SEX"] == 'F']

# %%
f.shape
# Out:
# (195, 12)

# %%
t_viz = df_1989.loc[df_1989["CONSTITUENCY"] == "VISAKHAPATNAM"]

# %%
t_viz.head()
# Out:
#         %                     CANDIDATE   CONSTITUENCY  No. PARTY SEX  \
# 10  50.31  UMA GAJAPATHI RAJU POOSAPATI  VISAKHAPATNAM    1   INC   F
# 11  46.63               M.V.V.S. MURTHY  VISAKHAPATNAM    2   TDP   M
# 12   1.05          GARIKINAANANDA KUMAR  VISAKHAPATNAM    3   BSP   M
# 13   1.05        GOLLAKOTI VISHNUMURTHY  VISAKHAPATNAM    4   IND   M
# 14   0.61              MAMIDI SOMUNAIDU  VISAKHAPATNAM    5   IND   M
#
#          TERRITORY   VOTES  TOTAL VOTES POLLED  TOTAL VALID VOTES  \
# 10  ANDHRA PRADESH  352326              733318             700337
# 11  ANDHRA PRADESH  326593              733318             700337
# 12  ANDHRA PRADESH    7370              733318             700337
# 13  ANDHRA PRADESH    7364              733318             700337
# 14  ANDHRA PRADESH    4240              733318             700337
#
#     TOTAL ELECTORS  TOTAL POLL PERCENTAGE
# 10         1073318                  68.32
# 11         1073318                  68.32
# 12         1073318                  68.32
# 13         1073318                  68.32
# 14         1073318                  68.32

# %%
tf = t_viz.loc[t_viz["SEX"] == 'F']

# %%
tf["No."][10]
# Out:
# 1

# %% [markdown]
# # what's up danger

# %%
tf["VOTES"][10]
# Out:
# 352326

# %%
round(8/3,2)
# Out:
# 2.67

# %%
temp = pd.DataFrame(data = [[1989,6,17,20,10.5]] ,columns = ['year','won','contested','total_participation','perc'])

# %%
temp
# Out:
#    year  won  contested  total_participation  perc
# 0  1989    6         17                   20  10.5

# %%
tc.size
# Out:
# 48

# %%
tc.shape
# Out:
# (4, 12)

# %%
def f1(state,year,df):
    
    t1 = df.loc[df["TERRITORY"] == state]
    const = list(t1["CONSTITUENCY"].unique())
    
    won = 0
    tv = 0
    tvw = 0
    total_c = 0
    tp = 0
    
    for i in const:
        
        tc = df.loc[df["CONSTITUENCY"] == i]
        ti = list(tc.index)
        tv += tc["TOTAL VALID VOTES"][ti[0]]
        tf = tc.loc[tc["SEX"] == 'F']
        
        if tf.shape[0] !=0:
            total_c += 1

        for j in list(tf.index):
            
            if tf["No."][j] == 1:
                won+=1
            
            tvw += tf["VOTES"][j]
            tp += 1
    
    if(tv == 0):
        perc = 0
    else:
        perc = round(tvw/tv,2)
    temp = pd.DataFrame(data = [[year,won,total_c,tp,perc]] ,columns = ['year','won','contested','total_participation','% of votes'])
    return temp

# %%
df_2004.head()
# Out:
#    AGE                CANDIDATES CATEGORY CONSTITUENCY  GENERAL VOTES POLLED  \
# 0   47     YERRANNAIDU KINJARAPU      GEN   SRIKAKULAM                361586
# 1   39           KILLI KRUPARANI      GEN   SRIKAKULAM                329432
# 2   49      DUNGA RANGARAO NAIDU      GEN   SRIKAKULAM                 13848
# 3   37       MYLAPALLI LAKSHMUDU      GEN   SRIKAKULAM                 13008
# 4   37  TAMMINENI JAGANMOHAN RAO      GEN   SRIKAKULAM                  4982
#
#    No PARTY  POSTAL VOTES POLLED SEX       TERRITORY  TOTAL VOTES POLLED  \
# 0   1   TDP                  320   M  ANDHRA PRADESH              723774
# 1   2   INC                  595   F  ANDHRA PRADESH              723774
# 2   5   IND                    0   M  ANDHRA PRADESH              723774
# 3   3   BSP                    3   M  ANDHRA PRADESH              723774
# 4   4   IND                    0   M  ANDHRA PRADESH              723774
#
#    TOTAL GENERAL VOTES POLLED  TOTAL POSTAL VOTES POLLED  TOTAL ELECTORS  \
# 0                      722856                        918          958626
# 1                      722856                        918          958626
# 2                      722856                        918          958626
# 3                      722856                        918          958626
# 4                      722856                        918          958626
#
#    TOTAL MEN ELECTORS  TOTAL WOMEN ELECTORS  % OF TOTAL VOTES  \
# 0              456636                501990         37.752575
# 1              456636                501990         34.427086
# 2              456636                501990          1.444568
# 3              456636                501990          1.357255
# 4              456636                501990          0.519702
#
#    TOTAL VOTES RECEIVED  % OF TOTAL POLLED
# 0                361906          50.002625
# 1                330027          45.598073
# 2                 13848           1.913304
# 3                 13011           1.797661
# 4                  4982           0.688336

# %%
df_2004["TOTAL VOTES RECEIVED"][0]*100/df_2004["TOTAL VOTES POLLED"][0]
# Out:
# 50.00262512883856

# %%
df_2004["SEX"][1] =='F'
# Out:
# True

# %%
df_2004["No"][0]
# Out:
# 1

# %%
def f2(state,year,df):
    
    t1 = df.loc[df["TERRITORY"] == state]
    const = list(t1["CONSTITUENCY"].unique())
    
    won = 0
    tv = 0
    tvw = 0
    total_c = 0
    tp = 0
    
    for i in const:
        
        tc = df.loc[df["CONSTITUENCY"] == i]
        ti = list(tc.index)
        tv += tc["TOTAL VOTES POLLED"][ti[0]]
        tf = tc.loc[tc["SEX"] == 'F']
        
        
        if tf.shape[0] !=0:
            total_c += 1

        for j in list(tf.index):
            
            if tf["No"][j] == 1:
                won+=1
            
            tvw += tf["TOTAL VOTES RECEIVED"][j]
            tp += 1
    
    if(tv == 0):
        perc = 0
    else:
        perc = round(tvw/tv,2)
    temp = pd.DataFrame(data = [[year,won,total_c,tp,perc]] ,columns = ['year','won','contested','total_participation','% of votes'])
    return temp

# %%
def func(state):
    
    temp = pd.DataFrame(columns = ['year','won','contested','total_participation','% of votes'])
    
    t1 = f1(state,1989,df_1989)
    t2 = f1(state,1991,df_1991)
    t3 = f1(state,1996,df_1996)
    t4 = f1(state,1998,df_1998)
    t5 = f1(state,1999,df_1999)
    t6 = f2(state,2004,df_2004)
    
    temp = temp.append(t1)
    temp = temp.append(t2)
    temp = temp.append(t3)
    temp = temp.append(t4)
    temp = temp.append(t5)
    temp = temp.append(t6)
    
    print("ANALYSIS FOR",state,'\n')
    print(temp.to_string(index=False))

# %%
func(states[0])
# Out:
# ANALYSIS FOR ANDHRA PRADESH
#
#  year won contested total_participation  % of votes
#  1989   5         7                   7        0.08
#  1991   2        20                  26        0.08
#  1996   3        24                  90        0.08
#  1998   2        14                  18        0.06
#  1999   8        12                  36        0.19
#  2004   5        17                  21        0.10

# %%
for i in states:
    func(i)
# Out:
# ANALYSIS FOR ANDHRA PRADESH
#
#  year won contested total_participation  % of votes
#  1989   5         7                   7        0.08
#  1991   2        20                  26        0.08
#  1996   3        24                  90        0.08
#  1998   2        14                  18        0.06
#  1999   8        12                  36        0.19
#  2004   5        17                  21        0.10
# ANALYSIS FOR ARUNACHAL PRADESH
#
#  year won contested total_participation  % of votes
#  1989   0         0                   0         0.0
#  1991   0         0                   0         0.0
#  1996   0         0                   0         0.0
#  1998   0         0                   0         0.0
#  1999   0         0                   0         0.0
#  2004   0         0                   0         0.0
# ANALYSIS FOR BIHAR
#
#  year won contested total_participation  % of votes
#  1989   2        16                  19        0.07
#  1991   3        23                  36        0.07
#  1996   3        30                  42        0.06
#  1998   4        20                  22        0.08
#  1999  10        18                  44        0.17
#  2004   1        10                  15        0.06
# ANALYSIS FOR GOA
#
#  year won contested total_participation  % of votes
#  1989   0         0                   0        0.00
#  1991   0         1                   2        0.00
#  1996   0         0                   0        0.00
#  1998   0         1                   1        0.00
#  1999   0         1                   2        0.01
#  2004   0         1                   1        0.01
# ANALYSIS FOR GUJARAT
#
#  year won contested total_participation  % of votes
#  1989   0         6                   9        0.06
#  1991   2        15                  17        0.06
#  1996   2        12                  18        0.05
#  1998   4         6                   7        0.08
#  1999   6         7                  16        0.20
#  2004   3         9                  11        0.09
# ANALYSIS FOR HARYANA
#
#  year won contested total_participation  % of votes
#  1989   0         2                   3        0.04
#  1991   1         5                   6        0.05
#  1996   1         8                   9        0.07
#  1998   1         5                   6        0.07
#  1999   4         3                   6        0.25
#  2004   0         6                   8        0.10
# ANALYSIS FOR HIMACHAL PRADESH
#
#  year won contested total_participation  % of votes
#  1989   0         1                   1        0.09
#  1991   0         2                   2        0.09
#  1996   0         2                   2        0.00
#  1998   0         1                   1        0.07
#  1999   0         2                   4        0.00
#  2004   1         2                   2        0.15
# ANALYSIS FOR JAMMU & KASHMIR
#
#  year won contested total_participation  % of votes
#  1989   0         1                   1        0.00
#  1991   0         0                   0        0.00
#  1996   0         5                   8        0.03
#  1998   0         2                   2        0.01
#  1999   0         3                  12        0.03
#  2004   0         3                   4        0.03
# ANALYSIS FOR KARNATAKA
#
#  year won contested total_participation  % of votes
#  1989   1         9                  12        0.03
#  1991   3        12                  15        0.06
#  1996   1        10                  71        0.04
#  1998   0         7                  10        0.04
#  1999   4         9                  22        0.16
#  2004   2        10                  10        0.06
# ANALYSIS FOR KERALA
#
#  year won contested total_participation  % of votes
#  1989   1         7                   8        0.09
#  1991   2         9                  10        0.10
#  1996   0         9                  10        0.05
#  1998   1         7                  10        0.10
#  1999   2        11                  26        0.12
#  2004   2        10                  15        0.11
# ANALYSIS FOR MADHYA PRADESH
#
#  year won contested total_participation  % of votes
#  1989   3        11                  20        0.09
#  1991   5        24                  39        0.09
#  1996   5        37                  75        0.11
#  1998   4        18                  28        0.08
#  1999   6        17                  46        0.19
#  2004   3        19                  30        0.11
# ANALYSIS FOR MAHARASHTRA
#
#  year won contested total_participation  % of votes
#  1989   2        14                  18        0.06
#  1991   3        24                  34        0.06
#  1996   2        27                  43        0.05
#  1998   2        18                  21        0.05
#  1999  10        14                  38        0.12
#  2004   6        21                  29        0.08
# ANALYSIS FOR MANIPUR
#
#  year won contested total_participation  % of votes
#  1989   0         1                   1        0.01
#  1991   0         0                   0        0.00
#  1996   0         2                   3        0.23
#  1998   1         1                   1        0.13
#  1999   0         2                   4        0.08
#  2004   1         1                   1        0.07
# ANALYSIS FOR MEGHALAYA
#
#  year won contested total_participation  % of votes
#  1989   0         0                   0        0.00
#  1991   0         0                   0        0.00
#  1996   0         1                   1        0.05
#  1998   0         2                   2        0.09
#  1999   0         0                   0        0.00
#  2004   0         0                   0        0.00
# ANALYSIS FOR MIZORAM
#
#  year won contested total_participation  % of votes
#  1989   0         0                   0         0.0
#  1991   0         0                   0         0.0
#  1996   0         0                   0         0.0
#  1998   0         0                   0         0.0
#  1999   0         0                   0         0.0
#  2004   0         0                   0         0.0
# ANALYSIS FOR NAGALAND
#
#  year won contested total_participation  % of votes
#  1989   0         0                   0         0.0
#  1991   0         0                   0         0.0
#  1996   0         0                   0         0.0
#  1998   0         0                   0         0.0
#  1999   0         0                   0         0.0
#  2004   0         0                   0         0.0
# ANALYSIS FOR ORISSA
#
#  year won contested total_participation  % of votes
#  1989   0         4                   4        0.03
#  1991   0         6                   6        0.02
#  1996   2         7                   8        0.06
#  1998   2         8                  10        0.08
#  1999   4         8                  16        0.21
#  2004   2         6                   9        0.10
# ANALYSIS FOR PUNJAB
#
#  year won contested total_participation  % of votes
#  1989   3         8                  11        0.13
#  1991   0         0                   0        0.00
#  1996   1         9                  17        0.10
#  1998   1         7                   9        0.08
#  1999   4         9                  28        0.37
#  2004   2         6                  10        0.19
# ANALYSIS FOR RAJASTHAN
#
#  year won contested total_participation  % of votes
#  1989   1         4                   5        0.06
#  1991   4        10                  14        0.08
#  1996   4        16                  25        0.07
#  1998   3        15                  20        0.10
#  1999   6        11                  30        0.23
#  2004   2        11                  17        0.09
# ANALYSIS FOR SIKKIM
#
#  year won contested total_participation  % of votes
#  1989   0         1                   1        0.22
#  1991   1         1                   2        0.91
#  1996   0         0                   0        0.00
#  1998   0         0                   0        0.00
#  1999   0         0                   0        0.00
#  2004   0         0                   0        0.00
# ANALYSIS FOR TAMIL NADU
#
#  year won contested total_participation  % of votes
#  1989   2         7                  11        0.04
#  1991   1        12                  17        0.07
#  1996   0        12                  15        0.01
#  1998   1        11                  13        0.03
#  1999   2        13                  34        0.08
#  2004   3        16                  23        0.08
# ANALYSIS FOR TRIPURA
#
#  year won contested total_participation  % of votes
#  1989   0         0                   0        0.00
#  1991   1         1                   2        0.39
#  1996   0         1                   2        0.01
#  1998   0         1                   1        0.00
#  1999   0         0                   0        0.00
#  2004   0         0                   0        0.00
# ANALYSIS FOR UTTAR PRADESH
#
#  year won contested total_participation  % of votes
#  1989   6        31                  43        0.07
#  1991   3        32                  52        0.06
#  1996   9        56                 109        0.07
#  1998   9        37                  58        0.08
#  1999  18        41                 122        0.19
#  2004   2        41                  63        0.09
# ANALYSIS FOR WEST BENGAL
#
#  year won contested total_participation  % of votes
#  1989   3         9                  11        0.10
#  1991   4        11                  16        0.08
#  1996   4        11                  21        0.10
#  1998   5        13                  21        0.13
#  1999  10        15                  52        0.20
#  2004   3        25                  34        0.12
# ANALYSIS FOR ANDAMAN & NICOBAR ISLANDS
#
#  year won contested total_participation  % of votes
#  1989   0         1                   1        0.00
#  1991   0         0                   0        0.00
#  1996   0         0                   0        0.00
#  1998   0         0                   0        0.00
#  1999   0         1                   2        0.01
#  2004   1         1                   1        0.02
# ANALYSIS FOR CHANDIGARH
#
#  year won contested total_participation  % of votes
#  1989   0         0                   0        0.00
#  1991   0         1                   1        0.00
#  1996   0         0                   0        0.00
#  1998   0         1                   2        0.00
#  1999   0         1                   6        0.01
#  2004   0         1                   1        0.00
# ANALYSIS FOR DADRA & NAGAR HAVELI
#
#  year won contested total_participation  % of votes
#  1989   0         1                   1        0.17
#  1991   0         1                   1        0.35
#  1996   0         0                   0        0.00
#  1998   0         0                   0        0.00
#  1999   0         0                   0        0.00
#  2004   0         1                   1        0.01
# ANALYSIS FOR DAMAN & DIU
#
#  year won contested total_participation  % of votes
#  1989   0         1                   1        0.18
#  1991   0         1                   2        0.03
#  1996   0         0                   0        0.00
#  1998   0         1                   1        0.00
#  1999   0         0                   0        0.00
#  2004   0         0                   0        0.00
# ANALYSIS FOR NATIONAL CAPITAL TERRITORY OF DELHI
#
#  year won contested total_participation  % of votes
#  1989   0         6                   8        0.03
#  1991   0         7                  20        0.04
#  1996   2         7                  24        0.11
#  1998   2         6                  10        0.24
#  1999   2         3                  14        0.13
#  2004   1         6                  15        0.07
# ANALYSIS FOR LAKSHADWEEP
#
#  year won contested total_participation  % of votes
#  1989   0         0                   0         0.0
#  1991   0         0                   0         0.0
#  1996   0         0                   0         0.0
#  1998   0         0                   0         0.0
#  1999   0         0                   0         0.0
#  2004   0         0                   0         0.0
# ANALYSIS FOR PONDICHERRY
#
#  year won contested total_participation  % of votes
#  1989   0         1                   1        0.07
#  1991   0         1                   1        0.03
#  1996   0         1                   1        0.04
#  1998   0         0                   0        0.00
#  1999   0         0                   0        0.00
#  2004   0         1                   1        0.36
